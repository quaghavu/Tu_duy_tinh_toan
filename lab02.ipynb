# %%
#w2a3
a, b = map(int, input("Nhap hai so nguyen: "). split())
print("tong=", a+b)
print("hieu=", a-b)
print("tich=", a*b)
print("phan nguyen=", a//b)
print("phan du=",a%b)
print("phep chia thuc=", round(a/b, 2))
# Out:
# Nhap hai so nguyen: 99 88
# tong= 187
# hieu= 11
# tich= 8712
# phan nguyen= 1
# phan du= 11
# phep chia thuc= 1.12

# %%
#w2a4
a1, b1, c1, a2, b2, a3 = map(float, input("nhap 6 dau diem: ").split())
print("diem trung binh mon la:", round((a1+b1+c1+a2*2+b2*2+a3*3)/10, 1))
# Out:
# nhap 6 dau diem: 9.87 9.88 9.65 9.43 8.32 9.776
# diem trung binh mon la: 9.4

# %%
#w2a5
a, b = map(int, input("nhap hai so: ").split())
print(a**b)
# Out:
# nhap hai so: 5 2
# 25

# %%
#w2a6
char = input("nhap mot ki tu tu a den z: ")
print(" ma unicode: ", ord(char))
print("ki tu in hoa: ", char.upper())
# Out:
# nhap mot ki tu tu a den z: b
#  ma unicode:  98
# ki tu in hoa:  B

# %%
#w2a7
print("A= ", ((13**2)*3)+5)
print("B= ", 13**2*3+5)
# Out:
# A=  512
# B=  512

# %%
#w2a8
C = float(input("nhiet do celcius: "))
print("nhiet do F la ", round(9/5*C+32, 2))
# Out:
# nhiet do celcius: 34.5443
# nhiet do F la  94.18

# %%
#w2a9
x = float(input("gia dong ho la (USD): "))
print("tong so tien dat phai tra la: ", round(x+10+x*0.4, 2))
# Out:
# gia dong ho la (USD): 8.9754
# tong so tien dat phai tra la:  22.57

# %%
#w2a11
h, m = map(int, input("nhap gio va phut: ").split())
print("so giay = ", h*60*60+m*60)
# Out:
# nhap gio va phut: 4 5
# so giay =  14700

# %%
#w2a12
n = int(input("nhap do dai canh: "))
print("so mieng dan can la: ", 6*n*n)
# Out:
# nhap do dai canh: 3
# so mieng dan can la:  54

# %%
#w2a13
a, b = map(int, input("nhap hai so nguyen duong: ").split())
tich = a*b
print("chu so hang don vi cua tich 2 so la: ", tich%10)
# Out:
# nhap hai so nguyen duong: 5 7
# chu so hang don vi cua tich 2 so la:  5

# %%
#w2a14
a, b = input("nhap hai so: ").split()
a, b = b, a
print(a, b)
# Out:
# nhap hai so: 1 2
# 2 1

# %%
#w2a15
n = int(input("nhap so nguyen n: "))
print("so sao la", 1+6*n*(n-1) )
# Out:
# nhap so nguyen n: 3
# so sao la 37
