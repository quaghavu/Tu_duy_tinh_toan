# %%
#w2a1
print("hello world!")
# Out:
# hello world!

# %%
#w2a2
ten = input("nhap ten cua ban: ")
print(f'xin chao {ten}')
# Out:
# nhap ten cua ban: ha
# xin chao ha

# %%
ten = input('Nhap ten cua ban: ')
print('xin chao', ten)
# Out:
# Nhap ten cua ban: ha
# xin chao ha

# %%
#w2a10
a, b, c = 'Bob', 'Alice', 'Helen'
print(f'Hi {c}, {b}, {a}')
# Out:
# Hi Helen, Alice, Bob

# %%
a, b, c = input("nhap ten cua ban: ").split()
print(f"hi, {c}, {b} va {a}")
# Out:
# nhap ten cua ban: vu quang ha
# hi, ha, quang va vu

# %%
#w2a16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#w2a17
print('*\n***\n*****')
# Out:
# *
# ***
# *****

# %%
for i in range(1,6,2):
  print("*"*i)
# Out:
# *
# ***
# *****

# %%
#w2a18
print("### ##  ### ###\n #  # #  #   #\n #  # #  #   #\n #  ##   #   #")
# Out:
# ### ##  ### ###
#  #  # #  #   #
#  #  # #  #   #
#  #  ##   #   #

# %%
a = ["### ##  ### ###", " #  # #  #   #", " #  # #  #   #", " #  ##   #   #"]
for i in a:
  print(i)
# Out:
# ### ##  ### ###
#  #  # #  #   #
#  #  # #  #   #
#  #  ##   #   #

# %%
#w2a19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#w2a20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#w2a21
def a():
  print("Hello world")
for bien in range(10):
  a()
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
